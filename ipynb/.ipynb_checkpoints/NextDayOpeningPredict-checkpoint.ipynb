# %% [markdown]
# # Try to Predict the Next Day's Opening Value
# ## Import Dependencies

# %%
import numpy as np
import tensorflow as tf
from tensorflow.contrib import learn
from tensorflow.contrib.learn.python import SKCompat
import scipy.io as sio
from sklearn import metrics
# sess = tf.InteractiveSession()

# %% [markdown]
# ## Import Data

# %%
# the data should be organized as [date, open, close, low, high, volume]
data = sio.loadmat('../daily_data.mat')['data']

# %% [markdown]
# Build Test and Train Datasets

# %%
data_len = data.shape[0]

# test data length
train_len = round(3 * data_len / 4)

x_train = data[0:train_len, :, :]
# start with just predicting the opening value the next day
y_train = data[1:train_len + 1, :, 1]

x_test = data[train_len + 1:-1, :, :]
# start with just predicting the opening value the next day
y_test = data[train_len + 2:, :, 1]

# let's start by just flattening the data
x_train = np.reshape(x_train, (train_len, -1))
x_test = np.reshape(x_test, (len(y_test), -1))

# %% [markdown]
# ## Build Neural Net and Train It

# %%
# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=x_train.shape[1])]

validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    x_test,
    y_test,
    every_n_steps=100)

classifier = learn.DNNRegressor(label_dimension=y_train.shape[1], feature_columns=feature_columns,
                                         hidden_units=[100, 50, 20],
                                model_dir="/tmp/opening_model",
                     config=tf.contrib.learn.RunConfig(save_checkpoints_secs=1))
classifier.fit(x=x_train, y=y_train, steps=10000, batch_size=100)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f34da693ac8>, '_num_ps_replicas': 0, '_model_dir': None, '_save_checkpoints_secs': 1, '_task_type': None, '_master': '', '_save_checkpoints_steps': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_environment': 'local', '_keep_checkpoint_every_n_hours': 10000, '_task_id': 0, '_is_chief': True, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_num_worker_replicas': 0, '_tf_random_seed': None, '_evaluation_master': ''}
# WARNING:tensorflow:From <ipython-input-4-9635dc515f08>:13: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-4-9635dc515f08>:13: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-4-9635dc515f08>:13: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Restoring parameters from /tmp/opening_model/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:loss = 6064.8, step = 10001
# INFO:tensorflow:Saving checkpoints for 10076 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 73.849
# INFO:tensorflow:loss = 6968.7, step = 10101 (1.355 sec)
# INFO:tensorflow:Saving checkpoints for 10162 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.1565
# INFO:tensorflow:loss = 6708.87, step = 10201 (1.051 sec)
# INFO:tensorflow:Saving checkpoints for 10253 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 97.7136
# INFO:tensorflow:loss = 7037.55, step = 10301 (1.023 sec)
# INFO:tensorflow:Saving checkpoints for 10359 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 104.679
# INFO:tensorflow:loss = 6374.52, step = 10401 (0.955 sec)
# INFO:tensorflow:Saving checkpoints for 10458 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 97.7929
# INFO:tensorflow:loss = 6881.81, step = 10501 (1.022 sec)
# INFO:tensorflow:Saving checkpoints for 10561 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 102.052
# INFO:tensorflow:loss = 6610.21, step = 10601 (0.980 sec)
# INFO:tensorflow:Saving checkpoints for 10664 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.3178
# INFO:tensorflow:loss = 7294.32, step = 10701 (1.049 sec)
# INFO:tensorflow:Saving checkpoints for 10751 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.0372
# INFO:tensorflow:loss = 7467.32, step = 10801 (1.052 sec)
# INFO:tensorflow:Saving checkpoints for 10851 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec:
into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.2735
# INFO:tensorflow:loss = 6448.73, step = 18201 (1.050 sec)
# INFO:tensorflow:Saving checkpoints for 18202 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 101.722
# INFO:tensorflow:loss = 6851.86, step = 18301 (0.983 sec)
# INFO:tensorflow:Saving checkpoints for 18305 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 103.987
# INFO:tensorflow:loss = 7758.92, step = 18401 (0.962 sec)
# INFO:tensorflow:Saving checkpoints for 18409 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 107.579
# INFO:tensorflow:loss = 6382.34, step = 18501 (0.930 sec)
# INFO:tensorflow:Saving checkpoints for 18517 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 102.225
# INFO:tensorflow:loss = 6717.71, step = 18601 (0.978 sec)
# INFO:tensorflow:Saving checkpoints for 18620 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 104.526
# INFO:tensorflow:loss = 6782.9, step = 18701 (0.957 sec)
# INFO:tensorflow:Saving checkpoints for 18726 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 105.514
# INFO:tensorflow:loss = 7184.08, step = 18801 (0.948 sec)
# INFO:tensorflow:Saving checkpoints for 18832 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 103.702
# INFO:tensorflow:loss = 6753.1, step = 18901 (0.964 sec)
# INFO:tensorflow:Saving checkpoints for 18938 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.7303
# INFO:tensorflow:loss = 5904.73, step = 19001 (1.045 sec)
# INFO:tensorflow:Saving checkpoints for 19027 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 87.9553
# INFO:tensorflow:loss = 7515.5, step = 19101 (1.138 sec)
# INFO:tensorflow:Saving checkpoints for 19118 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 19199 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 81.6758
# INFO:tensorflow:loss = 7341.44, step = 19201 (1.223 sec)
# INFO:tensorflow:Saving checkpoints for 19284 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 86.7749
# INFO:tensorflow:loss = 7391.3, step = 19301 (1.152 sec)
# INFO:tensorflow:Saving checkpoints for 19382 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 89.6829
# INFO:tensorflow:loss = 7285.62, step = 19401 (1.115 sec)
# INFO:tensorflow:Saving checkpoints for 19452 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 71.916
# INFO:tensorflow:loss = 6710.23, step = 19501 (1.391 sec)
# INFO:tensorflow:Saving checkpoints for 19518 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 19594 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 69.7454
# INFO:tensorflow:loss = 7251.39, step = 19601 (1.435 sec)
# INFO:tensorflow:Saving checkpoints for 19680 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 86.4755
# INFO:tensorflow:loss = 6345.51, step = 19701 (1.155 sec)
# INFO:tensorflow:Saving checkpoints for 19757 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 78.6707
# INFO:tensorflow:loss = 6720.2, step = 19801 (1.271 sec)
# INFO:tensorflow:Saving checkpoints for 19839 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 77.4384
# INFO:tensorflow:loss = 6967.72, step = 19901 (1.292 sec)
# INFO:tensorflow:Saving checkpoints for 19914 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 19997 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 20000 into /tmp/opening_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 7936.79.
# DNNRegressor(params={'hidden_units': [100, 50, 20], 'input_layer_min_slice_size': None, 'feature_columns': (_RealValuedColumn(column_name='', dimension=3006, default_value=None, dtype=tf.float32, normalizer=None),), 'activation_fn': <function relu at 0x7f34f8482d08>, 'embedding_lr_multipliers': None, 'head': <tensorflow.contrib.learn.python.learn.estimators.head._RegressionHead object at 0x7f34da693eb8>, 'gradient_clip_norm': None, 'optimizer': None, 'dropout': None})

# %%
classifier.evaluate(x_test, y_test)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:658: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:658: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-05-13-21:25:24
# INFO:tensorflow:Restoring parameters from /tmp/opening_model/model.ckpt-20000
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Finished evaluation at 2017-05-13-21:25:24
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, loss = 17186.8
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# {'global_step': 20000, 'loss': 17186.785}
